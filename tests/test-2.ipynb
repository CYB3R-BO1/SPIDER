# %% [markdown]
# # Test 2
# Quick smoke checks for new agents and stores.

# %%
# Basic imports (no execution side-effects)
from agents.heuristics_agent import HeuristicsAgent
from agents.dynamic_agent import DynamicAgent
from agents.verifier_agent import VerifierAgent
from agents.semantic_agent import SemanticAgent
from agents.z3_agent import Z3Agent
from storage.graph_store import GraphStore
from storage.sqlite_store import SQLiteStore
from storage.snapshots import SnapshotManager

print('Imports OK')
# Out:
# Imports OK

# %%
# Z3Agent sanity checks
z = Z3Agent()
print('Z3 feasible:', z.check_branch_feasible('1 + 1 == 2'))
print('Z3 infeasible:', z.check_branch_feasible('1 + 1 == 3'))
# Out:
# Z3 feasible: True
# Z3 infeasible: False

# %%
# SnapshotManager dry-run (no files written)
# Adjust db_path/root_dir if needed.
store = SQLiteStore(db_path='storage/metadata.db')
sm = SnapshotManager(store, root_dir='.')
print('SnapshotManager ready:', sm.root_dir)
# Out:
# SnapshotManager ready: c:\Users\cherr\Documents\MOST-LAB\AI-Reverse-Engineer

# %%
# NOTE: GraphStore and agents require Neo4j/GDB to be running and configured.
# This cell is a placeholder for integration testing.
print('Configure GraphStore / GDB to run full integration tests.')
# Out:
# Configure GraphStore / GDB to run full integration tests.
